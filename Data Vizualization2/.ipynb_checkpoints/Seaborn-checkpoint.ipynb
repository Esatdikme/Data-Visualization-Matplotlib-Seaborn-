# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction']]=df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction']].replace(0,np.nan)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df=df.fillna(value=df.idxmax())
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0     13.0  33.6
# 1              1     85.0           66.0           29.0     13.0  26.6
# 2              8    183.0           64.0          579.0     13.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0     13.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0          579.0     13.0  30.1
# 767            1     93.0           70.0           31.0     13.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.052871       0.173366       0.155492
# Glucose                      0.052871  1.000000       0.070377      -0.017372
# BloodPressure                0.173366  0.070377       1.000000       0.264883
# SkinThickness                0.155492 -0.017372       0.264883       1.000000
# Insulin                     -0.066404  0.153864      -0.106812      -0.422824
# BMI                          0.010138  0.006556       0.267768       0.098238
# DiabetesPedigreeFunction    -0.033523  0.060342      -0.030006      -0.150111
# Age                          0.544341  0.126859       0.257277       0.225368
# Outcome                      0.221898  0.290113       0.168555       0.060105
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.066404  0.010138                 -0.033523
# ...

# %%
#Heat graph of the data according to the correlation

sns.heatmap(df.corr(),annot=True,cmap="coolwarm",)
# Out:
# <AxesSubplot:>

# %%
# Histogram graph of glucose value

sns.histplot(df[["Glucose"]],x="Glucose")
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Count'>

# %%
# Density graph of glucose value

sns.kdeplot(df.Insulin,shade=True,color="r")
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Density'>

# %%
# Graph of the binary relations of variables

sns.pairplot(df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction','Outcome']])

# %%
# Diabetes graph by the number of pregnancies

sns.countplot(x="Pregnancies",hue="Outcome",data=df[["Pregnancies","Outcome"]])
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='count'>

# %%
# Diabetes graph of those whose blood pressure is greater than 30

sns.boxplot(x="Outcome",y="BloodPressure", data=df[df["BloodPressure"]>30])
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='BloodPressure'>
